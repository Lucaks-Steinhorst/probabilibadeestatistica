# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucaks-Steinhorst/probabilibadeestatistica/blob/master/Lista_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Lucas Steinhorst
# Lista 4

# Ex 1:

#Escreva um programa para ler o número de lados de um polígono regular e a
#medida do lado (em cm). Calcular e imprimir o seguinte: − Se o número de lados
#for igual a 3 escrever TRIÂNGULO e o valor da área − Se o número de lados for
#igual a 4 escrever QUADRADO e o valor da sua área. − Se o número de lados for
#igual a 5 escrever PENTÁGONO.
''' 
nLados = int(input('Insira o número de lados de um polígono regular: '))
tLados = int(input('Insira a medida do lado (em cm): '))

if nLados == 3:
  area = ((tLados**2)/4)*1.73205080757 # 1.73205080757 = raiz de 3, podia ter feito 3**(1/2) tbm
  print('Este é um TRIÂNGULO e sua área é de ', round(area,2),'cm quadrados.')
elif nLados == 4:
  area = tLados**2
  print('Este é um QUADRADO e sua área é de ', round(area,2),'cm quadrados.')   
elif nLados == 5:
  area = (tLados*5/2)*((tLados/2)/0.726542528) #area=semi perimetro*apotema do pentagono regular, ficou muito preciso
  print('Este é um PENTÁGONO e sua área é de ', round(area,2),'cm quadrados.') '''

# Ex 2:

#Acrescente as seguintes mensagens à solução do exercício anterior conforme o
#caso. − Caso o número de lados seja inferior a 3 escrever NÃO É UM
#POLÍGONO. − Caso o número de lados seja superior a 5 escrever POLÍGONO
#NÃO IDENTIFICADO.
'''
nLados = int(input('Insira o número de lados de um polígono regular: '))
tLados = int(input('Insira a medida do lado (em cm): '))

if nLados < 3:  #nao pode ser menor que 3
  while True:
    print('NÃO É UM POLÍGONO.')
    nLados = int(input('Insira o número de lados de um polígono regular novamente: '))
    tLados = int(input('Insira a medida do lado (em cm) novamente: '))
    if nLados >= 3:
      break
if nLados > 5:  #nao pode ser maior que 5
  while True:
    print('POLÍGONO NÃO IDENTIFICADO.')
    nLados = int(input('Insira o número de lados de um polígono regular novamente: '))
    tLados = int(input('Insira a medida do lado (em cm) novamente: '))
    if nLados <= 5:
      break     
if nLados == 3:
  area = ((tLados**2)/4)*1.73205080757  # 1.73205080757 = raiz de 3, podia ter feito 3**(1/2) tbm
  print('Este é um TRIÂNGULO e sua área é de', round(area,2),'cm quadrados.')
elif nLados == 4:
  area = tLados**2
  print('Este é um QUADRADO e sua área é de', round(area,2),'cm quadrados.')   
elif nLados == 5:
  area = (tLados*5/2)*((tLados/2)/0.726542528) #area=semi perimetro*apotema do pentagono regular, ficou muito preciso
  print('Este é um PENTÁGONO e sua área é de', round(area,2),'cm quadrados.')  '''    

# Ex 3:

#Escreva um programa para ler 3 valores inteiros e escrever o maior deles.
#Considere que o usuário não informará valores iguais.
''' 
n1 = int(input('Insira o primeiro valor: '))
n2 = int(input('Insira o segundo valor: '))
n3 = int(input('Insira o terceiro valor: '))
lista = [n1, n2, n3]
lista.sort()  #o .sort vai ordenar na ordem crescente
print('O maior valor é o:',lista[2]) '''

# Ex 4:

#Escreva um programa que leia as medidas dos lados de um triângulo e escreva
#se ele é Equilátero, Isósceles ou Escaleno. Sendo que: − Triângulo Equilátero:
#possui os 3 lados iguais. − Triângulo Isóscele: possui 2 lados iguais. − Triângulo
#Escaleno: possui 3 lados diferentes.
''' 
n1 = int(input('Insira o valor do primeiro lado: '))
n2 = int(input('Insira o valor do segundo lado: '))
n3 = int(input('Insira o valor do terceiro lado: '))

if n1==n2==n3:
  print('Este é um Triângulo Equilátero')
elif n1==n2 or n1==n3 or n2==n3:
  print('Este é um Triângulo Isósceles')  
else :
  print('Este é um Triângulo Escaleno')  '''

# Ex 5: 

#Escreva um programa que leia o valor de 3 ângulos de um triângulo e escreva se 
#o triângulo é Acutângulo, Retângulo ou Obtusângulo. Sendo que: − Triângulo
#Retângulo: possui um ângulo reto. (igual a 90º) − Triângulo Obtusângulo: possui
#um ângulo obtuso. (maior que90º) − Triângulo Acutângulo: possui três ângulos
#agudos. (menor que 90º)
''' 
a1 = float(input('Insira o valor do primeiro lado: '))
a2 = float(input('Insira o valor do segundo lado: '))
a3 = float(input('Insira o valor do terceiro lado: '))
lista = [a1, a2, a3]
lista.sort()   #nesse caso o .sort ajuda a sempre deixar o maior angulo no a3
if a3==90:
  print('Este é um Triângulo Retângulo')
elif a3<90:
  print('Este é um Triângulo Acutângulo:')  
elif a3>90:
  print('Este é um Triângulo Obtusângulo') '''

# Ex 6:

#Faça um programa para ler um número inteiro e imprimir todos os números de 0
#até o número lido.
''' 
num = int(input('Insira um número e te mostrarei todos os numeros de 0 até esse número: ')) 
for num in range(0,num+1):   # range de 0 até num
  print(num) '''

# Ex 7:

#Solicitar um número entre 1 e 4. Se a pessoas digitar um número diferente,
#mostrar a mensagem "entrada inválida" e solicitar o número novamente. Se
#digitar correto mostrar o número digitado.
''' 
num = float(input('Insira o valor entre 1 e 4: '))
if num < 1 or num > 4:
  while True:   #loop para numeros diferentes
    print('Entrada inválida"')
    num = float(input('Insira o valor entre 1 e 4 novamente: '))
    if num >=1 and num <=4 :
      break
if num >=1 and num <=4:
  print(num) '''

#Ex 8:

#Fazer um programa que receba vários valores inteiros no teclado (um valor a
#cada iteração) e determine o maior dos colocados desde o inicio do programa. A
#condição de término do programa é quando o usuário digitar zero.
''' 
lista= []
while True:
  num = int(input('Insira o valor: '))
  lista.append(num)  #.append para colocar no final da lista
  lista.sort()       #.sort para o maior sempre ficar no final
  ultimo = lista[-1] #lista[-1] para aparecer o ultimo da lista
  if num == 0:
    break 
print('O maior valor é:',ultimo) '''   

#Ex 9:

#Escreva um programa Python que leia um número inteiro positivo de 4 dígitos,
#calcule e mostre a sua decomposição em unidade, dezena, centena e milhar:
#Exemplo: 8531; unidade = 1 dezena = 3 centena = 5 5 milhar = 8

#Nao achei uma maneira melhor entao apelei pra matemática 
''' 
num = int (input("Digite um número inteiro positivo de 4 dígitos: ")) 
u = num%10     #uso o modulo da divisao
d = num//10%10
c = num//100%10
m = num//1000%10
print('Unidade =', u, '\nDezena =', d, '\nCentena =', c, '\nMilhar =',m) ''' 

#Esse programa é de quebrar a cabeça, muito interessante.
